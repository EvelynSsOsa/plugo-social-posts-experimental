# %% [markdown]
# <a href="https://colab.research.google.com/github/EvelynSsOsa/plugo-social-posts-experimental/blob/colab-upload/generador_posts_plugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("¡Hola Plugo desde Colab! 🚀")
# Out:
# ¡Hola Plugo desde Colab! 🚀
